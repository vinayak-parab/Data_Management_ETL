# %%
import pandas as pd
import mysql.connector
print("packages imported")
# Out:
# packages imported

# %%
mydb = mysql.connector.connect(host='localhost', database='salesdb', user='root', password='Csoares#12')
df = pd.read_sql('SELECT * FROM sales_data', con=mydb)
df
# Out:
#         SalesID  CustomerID CustFirstName CustMiddleInitial CustLastName  \
# 0             4        4182      Clarence                 L         Zeng
# 1             9           1         Aaron                 4    Alexander
# 2            20        4182      Clarence                 L         Zeng
# 3            25           1         Aaron                 4    Alexander
# 4            33       13482         Mario                 H          Rai
# ...         ...         ...           ...               ...          ...
# 129464   129366       16281       Richard                 M        Brown
# 129465   129399        7477         Glenn              None           Lu
# 129466   129427       10738         Julie                 M          Luo
# 129467   129430       16281       Richard                 M        Brown
# 129468   129463        7477         Glenn              None           Lu
#
#         EmployeeID EmpFirstName EmpMiddleInitial EmpLastName  ProductID  \
# ...

# %%
mycursor = mydb.cursor()

# %%
sql = "UPDATE sales_data SET CustMiddleInitial = NULL where CustMiddleInitial = '4' "
mycursor.execute(sql)
mydb.commit()
print(mycursor.rowcount, "record(s) affected")
# Out:
# 14394 record(s) affected
